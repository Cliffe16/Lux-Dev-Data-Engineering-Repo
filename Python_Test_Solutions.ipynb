# %% [markdown]
# <a href="https://colab.research.google.com/github/Cliffe16/Lux-Dev-Data-Engineering-Repo/blob/main/Python_Test_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SECTION A

# %%
name = "Cliffe"
print(name)
# Out:
# Cliffe

# %%
x = 4
y = 6

print(f"Sum: {x+y}; Difference: {x-y}; Product: {x*y}; Division: {x/y}")
# Out:
# Sum: 10; Difference: -2; Product: 24; Division: 0.6666666666666666

# %%
x=5
y=10

x = x+y
y = x-y
x = x-y

print(f"x: {x}; y: {y}")
# Out:
# x: 10; y: 5

# %%
age = int(input("Enter age:"))

if age >= 18:
  print("Adult")
else:
  print("Minor")
# Out:
# Enter age:54
# Adult

# %%
text = "programming"

text.count("g")
# Out:
# 2

# %%
string ="100"
num = int(string)
int_sum = num + 25

print(int_sum)
# Out:
# 125

# %%
new_list =  [4, 9, 1, 7, 3]
print(max(new_list))
# Out:
# 9

# %%
new_list = [1, 2, 3, 4, 5]
new_list.reverse()

print(new_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
user_info = {"name": "Cliffe", "age": 51, "country": "Kenya"}
user_info["age"]
# Out:
# 51

# %%
new_tuple = (4, 5, 6, 8)
new_list = list(new_tuple)
new_list
# Out:
# [4, 5, 6, 8]

# %% [markdown]
# SECTION B

# %%
num = int(input("Enter a number: "))

if num%2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number: 5
# The number is odd

# %%
num = int(input("Enter a number: "))

if num > 0:
  print("The number is positive")
elif num < 0:
  print("The number is negative")
else:
  print("The number is zero")
# Out:
# Enter a number: 5
# The number is positive

# %%
year = int(input("Enter year: "))

if year%4 == 0:
  print("The year is leap")
else:
  print("The year is non-leap")
# Out:
# Enter year: 2025
# The year is non-leap

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

if num1 > num2:
  print(f"{num1} is greater")
else:
  print(f"{num2} is greater")
# Out:
# Enter the first number: 5
# Enter the second number: 7
# 7 is greater

# %%
marks = int(input("Enter Marks: "))

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Marks: 45
# Fail

# %%
character = input("Enter character: ")
vowels = ("a", "e", "i", "o", "u")

if character in vowels:
  print("vowel")
else:
  print("consonant")
# Out:
# Enter character: z
# consonant

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

numbers = (num1, num2, num3)

print(max(numbers))
# Out:
# Enter the first number: 4
# Enter the second number: 5
# Enter the third number: 3
# 5

# %% [markdown]
# Conditional solution

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

if num1 > num2:
  print(f"{num1} is greatest")
elif num3 > num2:
  print(f"{num3} is greatest")
else:
  print(f"{num2} is greatest")
# Out:
# Enter the first number: 4
# Enter the second number: 5
# Enter the third number: 3
# 5 is greatest

# %%
num = int(input("Enter the number: "))

if num%3==0 and num%5==0:
  print("The number is divisible by both 3 and 5")
elif num%3==0:
  print("The number is  divisible by 3 only")
elif num%5==0:
  print("The number is  divisible by 5 only")
else:
  print("The number is not divisible")
# Out:
# Enter the number: 15
# The number is divisible by both 3 and 5
